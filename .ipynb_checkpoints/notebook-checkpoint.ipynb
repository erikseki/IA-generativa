# %%
df = pd.read_csv(r'C:\Users\Erik\Desktop\IA-generativa\comments_amazon.csv', sep=',')
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv(r'C:\Users\Erik\Desktop\IA-generativa\comments_amazon.csv', sep=',')
#       2 df.head()
#
# NameError: name 'pd' is not defined
